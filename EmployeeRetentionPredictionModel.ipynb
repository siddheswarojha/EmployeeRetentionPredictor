# %%
#importing necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as nmp
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
#adding dummy data to handle categorical values
newDF= pd.get_dummies(df.salary)
newDF
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
#merging the both dataframes
finalDF = pd.concat([df,newDF],axis='columns')
finalDF
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
bestDF = finalDF.drop(['salary','low'],axis='columns')
bestDF
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X= bestDF.drop(['left','Department'],axis='columns')
X
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
y=bestDF.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
#splitting the data for training and testing 
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2468                 0.91             0.76               5
# 8200                 0.21             0.49               3
# 14117                0.69             0.54               3
# 10971                0.80             0.80               4
# 7883                 0.95             0.83               4
# ...                   ...              ...             ...
# 9125                 0.81             0.97               3
# 9537                 0.93             0.98               4
# 6316                 0.78             0.50               4
# 13270                0.68             0.97               3
# 13008                0.73             0.86               3
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2468                    152                   3              0
# 8200                    253                   3              0
# 14117                   164                   7              0
# ...

# %%
y_train
# Out:
# 2468     0
# 8200     0
# 14117    0
# 10971    0
# 7883     0
#         ..
# 9125     0
# 9537     0
# 6316     0
# 13270    0
# 13008    0
# Name: left, Length: 11999, dtype: int64

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 13075                0.79             0.65               5
# 8984                 0.82             0.87               3
# 754                  0.66             0.93               5
# 5557                 0.77             0.52               3
# 6604                 0.19             0.85               6
# ...                   ...              ...             ...
# 10824                0.77             0.50               3
# 7571                 0.60             0.58               3
# 11650                0.97             0.38               5
# 13169                0.88             0.72               5
# 13588                0.95             0.50               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 13075                   215                   2              1
# 8984                    206                   2              0
# 754                     253                   5              0
# ...

# %%
y_test
# Out:
# 13075    0
# 8984     0
# 754      1
# 5557     0
# 6604     0
#         ..
# 10824    0
# 7571     0
# 11650    0
# 13169    0
# 13588    0
# Name: left, Length: 3000, dtype: int64

# %%
model = linear_model.LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#accuracy
model.score(X_test,y_test)
# Out:
# 0.7743333333333333
